# %% [markdown]
# <a href="https://colab.research.google.com/github/sey2on/pythonbasicclass/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#코랩에서 한글출력

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
# 데이터 시각화

#  data visualization 이란 데이터를 분석한 결과를 사용자가 쉽게 이해할수 있도록
#  표현하여 전달하는 것을 의미한다. 

# 파이썬에서 시각화 도구 matplotlib seaborn (R ggplot2)

#!pip install matplotlib

# %%
import matplotlib.pyplot as plt  # 긴 이름을 plt 로 줄여서 사용

plt.plot([1,2,3,4])

plt.show()
#리스트의 값들을 y값이라고 가정하고 x는 자동으로 생성된다.

# %%
plt.plot([1,2,3,4],[1,4,9,6]) #각각 순서대로 x축의 값과 y축의 값으로 그린다. 
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,6], 'ro')  #빨강 r 원형 o 마커로 표현
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,6], 'b-')  # 블루의 실선으로 표현
plt.show()

# %%
data_dict = {'data_x':[1,2,3,4,5], 'data_y':[2,4,5,10,8]}

plt.plot('data_x', 'data_y', data=data_dict)

plt.show()

# %%
# x축과 y축에 이름 넣기

data_dict = {'data_x':[1,2,3,4,5], 'data_y':[2,4,5,10,8]}

plt.plot('data_x', 'data_y', data=data_dict)
plt.xlabel('X축')
plt.ylabel('Y축')

plt.show()

# %%
# 라벨을 꾸미기

data_dict = {'data_x':[1,2,3,4,5], 'data_y':[2,4,5,10,8]}

plt.plot('data_x', 'data_y', data=data_dict)
plt.xlabel('X축', fontdict = {'color':'b', 'size':'xx-large'})
plt.ylabel('Y축',fontdict = {'color':'r', 'size':14 })             

plt.show()

# %%
# 범례 lengend

data_dict = {'data_x':[1,2,3,4,5], 'data_y':[2,4,5,10,8]}

plt.plot('data_x', 'data_y', data=data_dict)
plt.xlabel('X축', fontdict = {'color':'b', 'size':'xx-large'})
plt.ylabel('Y축',fontdict = {'color':'r', 'size':14 })             
plt.legend()
plt.show()

# %%
data_dict = {'data_x':[1,2,3,4,5], 'data_y':[2,4,5,10,8]}

plt.plot('data_x', 'data_y', data=data_dict, label = "Price ($)")
plt.xlabel('X축', fontdict = {'color':'b', 'size':'xx-large'})
plt.ylabel('Y축',fontdict = {'color':'r', 'size':14 })             
plt.legend()
plt.show()

# %%
# 범례의 위치


data_dict = {'data_x':[1,2,3,4,5], 'data_y':[2,4,5,10,8]}

plt.plot('data_x', 'data_y', data=data_dict, label = "Price ($)")
plt.xlabel('X축', fontdict = {'color':'b', 'size':'xx-large'})
plt.ylabel('Y축',fontdict = {'color':'r', 'size':14 })             
plt.legend(loc = 8)  # loc  설정으로그래프상에 범례의 위치를 지정할 수 있다. 
plt.show()           # 범례 위치 설정을 생략하면 자동으로 적당한 위치를 알아서 결정한다.

# %%
data1 = {'data_x':[1,2,3,4,5], 'data_y':[2,4,5,10,8]}
data2 = {'data_x':[1,2,3,4,5], 'data_y':[3,5,9,7,7]}

plt.plot('data_x', 'data_y', data=data1, label = "Price ($)")
plt.plot('data_x', 'data_y', data=data2, label = "Demand (#)")

plt.xlabel('X축', fontdict = {'color':'b', 'size':'xx-large'})
plt.ylabel('Y축',fontdict = {'color':'r', 'size':14 })             
plt.legend(loc = 0) 
plt.show()

# %%
data1 = {'data_x':[1,2,3,4,5], 'data_y':[2,4,5,10,8]}
data2 = {'data_x':[1,2,3,4,5], 'data_y':[3,5,9,7,7]}

plt.plot('data_x', 'data_y', data=data1, label = "Price ($)")
plt.plot('data_x', 'data_y', data=data2, label = "Demand (#)")

plt.xlabel('X축', fontdict = {'color':'b', 'size':'xx-large'})
plt.ylabel('Y축',fontdict = {'color':'r', 'size':14 })             
plt.legend(loc = 0, ncol=2) # 범례의 모양을 결정 
plt.show()

# %%
data1 = {'data_x':[1,2,3,4,5], 'data_y':[2,4,5,10,8]}
data2 = {'data_x':[1,2,3,4,5], 'data_y':[3,5,9,7,7]}

plt.plot('data_x', 'data_y', data=data1, label = "Price ($)")
plt.plot('data_x', 'data_y', data=data2, label = "Demand (#)")

plt.xlabel('X축', fontdict = {'color':'b', 'size':'xx-large'})
plt.ylabel('Y축',fontdict = {'color':'r', 'size':14 })             
plt.legend(loc = 0, ncol=2, fontsize=12, shadow=True) 
plt.show()

# %%
data1 = {'data_x':[1,2,3,4,5], 'data_y':[2,4,5,10,8]}
data2 = {'data_x':[1,2,3,4,5], 'data_y':[3,5,9,7,7]}

plt.plot('data_x', 'data_y', data=data1, label = "Price ($)")
plt.plot('data_x', 'data_y', data=data2, label = "Demand (#)")

plt.xlabel('X축', fontdict = {'color':'b', 'size':'xx-large'})
plt.ylabel('Y축',fontdict = {'color':'r', 'size':14 })             
plt.legend(loc = 0, ncol=2, fontsize=12, frameon=False) 
plt.show()

# %%
# 축 설정

plt.plot([1,2,3,4],[2,3,5,10])

plt.show()

# %%
plt.plot([1,2,3,4],[2,3,5,10])
plt.axis('square')
plt.show()

# %%
plt.plot([1,2,3,4],[2,3,5,10])
plt.axis('square')
plt.xlabel('X축')
plt.ylabel('Y축')
plt.show()

# %%
plt.plot([1,2,3,4],[2,3,5,10])
plt.axis('scaled')
plt.xlabel('X축')
plt.ylabel('Y축')
plt.show()

# %%
# 특별한 설정이 없으면 그래프는 실선으로 그려지지만...

plt.plot([1,2,3,4],[2,3,5,10], 'ro')
plt.axis('scaled')
plt.xlabel('X축')
plt.ylabel('Y축')
plt.show()

# %%
plt.plot([1,2,3,4],[2,3,5,10], 'bo--')
plt.axis('scaled')
plt.xlabel('X축')
plt.ylabel('Y축')
plt.show()

# %%
# 여러 그래프 함께 그리기

plt.plot([1,2,3,4], [2,3,3,6], 'r-')
plt.plot([1,2,3,4], [2,3,5,10], 'b--')
plt.plot([1,2,3,4], [2,4,8,12], 'g:')
plt.xlabel('X축')
plt.ylabel('Y축')
plt.show()

# %%
plt.plot([1,2,3,4], [2,3,3,6], 'r-')
plt.plot([1,2,3,4], [2,3,5,10], 'b--')
plt.plot([1,2,3,4], [2,4,8,12], 'g:')
plt.xlabel('X축')
plt.ylabel('Y축')
plt.title('그래프 제목')
plt.show()

# %%
# 막대 그래프 - 값의 변화, 증가 감소

import numpy as np  # 계산 관련 모듈
import pandas as pd # 데이터 분석 관련 모듈


years = ['2019','2020','2021']
values = [100,400,900]

plt.bar(years, values)
plt.show()

# %%
import numpy as np  # 계산 관련 모듈
import pandas as pd # 데이터 분석 관련 모듈


years = ['2019','2020','2021']
values = [100,400,900]

plt.bar(years, values, width=0.4, color='green')

plt.show()

# %%
years = ['한국','일본','미국']
values = [100,400,900]

plt.barh(years, values, color='green')

plt.show()

# %%
# 산점도  scatter plot 분포를 나타내기에 적합

import numpy as np

np.random.seed(20)     # 항상 일정한 값으로 난수 발생

n = 50

a = (30 * np.random.rand(n)) ** 2
x = np.random.rand(n)  # 0 ~ 1 사이로 난수 발생
y = np.random.rand(n)
colors = np.random.rand(n)


plt.scatter(x,y, c = colors, s = a, alpha = 0.4)
plt.show()

# %%
import numpy as np

np.random.seed(20)     # 항상 일정한 값으로 난수 발생

n = 50

a = (30 * np.random.rand(n)) ** 2
x = np.random.rand(n)  # 0 ~ 1 사이로 난수 발생
y = np.random.rand(n)
z = np.random.rand(n)
colors = np.random.rand(n)


# plt.scatter(x,y, c = colors, s = a, alpha = 0.4)
fig = plt.figure(figsize = (10,10))  # 액자 설정
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z, s= a, c=colors, alpha=0.4 )

plt.show()

# %%
# 타이타닉 시각화

import numpy as np               # 데이터 계산 관련 모듈
import pandas as pd              # 데이터 분석 관련 모듈
import matplotlib.pyplot as plt  # 데이터 시각화 관련 모듈
import seaborn as sns            # 데이터 시각화 관련 모듈

# %%
rawdata = pd.read_csv('titanic.csv')

# %%
rawdata.head()  # 데이터 셋의 시작 일부분 확인
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
rawdata.info()  #데이터셋의 정보보기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   float64
#  1   survived   1309 non-null   float64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   float64
#  6   parch      1309 non-null   float64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 143.4+ KB

# %%
rawdata.describe()  # 요약 통계량 보기
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
rawdata  # 판다스로 읽어온 csv나 excel 은 데이터프레임으로 기본적으로 가오게 된다.
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
type(rawdata)
# Out:
# pandas.core.frame.DataFrame

# %%
rawdata['survived'].value_counts()
# Out:
# 0.0    809
# 1.0    500
# Name: survived, dtype: int64

# %%
rawdata['survived'].value_counts().plot.pie()

# %%
rawdata['survived'].value_counts().plot.pie(autopct='%1.2f%%')
plt.show()

# %%
sns.countplot('survived', data=rawdata)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
rawdata['age'].hist(bins=20)

# %%
rawdata.corr()
# Out:
#             pclass  survived       age     sibsp     parch      fare      body
# pclass    1.000000 -0.312469 -0.408106  0.060832  0.018322 -0.558629 -0.034642
# survived -0.312469  1.000000 -0.055513 -0.027825  0.082660  0.244265       NaN
# age      -0.408106 -0.055513  1.000000 -0.243699 -0.150917  0.178739  0.058809
# sibsp     0.060832 -0.027825 -0.243699  1.000000  0.373587  0.160238 -0.099961
# parch     0.018322  0.082660 -0.150917  0.373587  1.000000  0.221539  0.051099
# fare     -0.558629  0.244265  0.178739  0.160238  0.221539  1.000000 -0.043110
# body     -0.034642       NaN  0.058809 -0.099961  0.051099 -0.043110  1.000000

# %%
sns.heatmap(rawdata.corr(), annot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.barplot('pclass','survived', data=rawdata)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot('sex','survived', data=rawdata)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot('parch','survived', data=rawdata)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot('sibsp','survived', data=rawdata)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
